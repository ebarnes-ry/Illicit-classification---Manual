# %%
from tqdm import tqdm
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import datetime
from datetime import date
pd.set_option('display.max_columns', None)
import time
start_time = time.time()

# %%
engine = create_engine('mysql+mysqlconnector://' + 'bob' + ':' + '0akcabin3t' + '@' + 'localhost' + ':' + '3307' + '/imi', echo=False)

# %%
run_time_request='Q3_082023'
state_request ='Virginia'
county_request ='("")'
city_request = '("Arlington")'

# %%
if county_request =='("")':
    county_variable = "#"
else:
    county_variable = 'AND county_fix in '+county_request

if city_request == '("")':
    city_variable ='#'
else:
    city_variable = 'AND city_fix in '+city_request
############################# RM LOGIC QUERY ###############################

############################# AS LOGIC QUERY ###############################
if county_request =='("")':
    arcounty_variable = "#"
else:
    arcounty_variable = 'AND county in  '+county_request

if city_request == '("")':
    arcity_variable ='#'
else:
    arcity_variable = 'AND city in '+city_request

# %%
query_2='''SELECT i.imb_id,i.identifier, r.imb_identifier, i.imb_name, r.review_head_id, i.address, i.city_fix, i.county_fix, i.zip, r.visit_date, r.time_of_visit, r.paid_to_house, r.extra_tip, r.message1, r.message2, i.url, r.review_id, r.review_head_date, r.finger,r.kiss,r.lick,r.fs,r.breast_play,r.blowjob,r.ass_play,r.hand_job,r.prostate_massage
FROM imb i
LEFT JOIN reviews r
	ON i.identifier = r.imb_identifier
WHERE run_time = "'''+run_time_request+'''"
AND is_erotic = 1
AND permanently_closed = 0
'''+'''
AND state = "'''+state_request+'''"
'''+county_variable+'''
'''+city_variable+'''
'''+'''
GROUP BY r.review_head_id'''
df_kitems = pd.read_sql(query_2, engine)
df_kitems.dropna(subset=['review_head_date'], inplace = True)
df_kitems.head(200)
# Out:
#       imb_id                                         identifier  \
# 0    1666555  Q3_082023Shirlington Therapy703-920-00102249 S...
# 1    1666555  Q3_082023Shirlington Therapy703-920-00102249 S...
# 2    1666555  Q3_082023Shirlington Therapy703-920-00102249 S...
# 3    1666555  Q3_082023Shirlington Therapy703-920-00102249 S...
# 4    1666555  Q3_082023Shirlington Therapy703-920-00102249 S...
# ..       ...                                                ...
# 196  1666602  Q3_082023Live Massage Spa703-933-88195555 Colu...
# 197  1666602  Q3_082023Live Massage Spa703-933-88195555 Colu...
# 198  1666602  Q3_082023Live Massage Spa703-933-88195555 Colu...
# 199  1666602  Q3_082023Live Massage Spa703-933-88195555 Colu...
# 200  1666602  Q3_082023Live Massage Spa703-933-88195555 Colu...
#
#                                         imb_identifier             imb_name  \
# 0    Q3_082023Shirlington Therapy703-920-00102249 S...  Shirlington Therapy
# 1    Q3_082023Shirlington Therapy703-920-00102249 S...  Shirlington Therapy
# 2    Q3_082023Shirlington Therapy703-920-00102249 S...  Shirlington Therapy
# 3    Q3_082023Shirlington Therapy703-920-00102249 S...  Shirlington Therapy
# 4    Q3_082023Shirlington Therapy703-920-00102249 S...  Shirlington Therapy
# ..                                                 ...                  ...
# 196  Q3_082023Live Massage Spa703-933-88195555 Colu...     Live Massage Spa
# 197  Q3_082023Live Massage Spa703-933-88195555 Colu...     Live Massage Spa
# 198  Q3_082023Live Massage Spa703-933-88195555 Colu...     Live Massage Spa
# 199  Q3_082023Live Massage Spa703-933-88195555 Colu...     Live Massage Spa
# 200  Q3_082023Live Massage Spa703-933-88195555 Colu...     Live Massage Spa
#
#     review_head_id                                            address  \
# 0          2123688  2249 S Shirlington Rd #C Arlington, Virginia 2...
# 1          1744589  2249 S Shirlington Rd #C Arlington, Virginia 2...
# 2          1681676  2249 S Shirlington Rd #C Arlington, Virginia 2...
# 3          1664628  2249 S Shirlington Rd #C Arlington, Virginia 2...
# 4          1558651  2249 S Shirlington Rd #C Arlington, Virginia 2...
# ..             ...                                                ...
# 196        1212531  5555 Columbia Pike, Suite 101 Arlington, Virgi...
# 197        1153932  5555 Columbia Pike, Suite 101 Arlington, Virgi...
# 198        1035503  5555 Columbia Pike, Suite 101 Arlington, Virgi...
# 199         973592  5555 Columbia Pike, Suite 101 Arlington, Virgi...
# 200         928894  5555 Columbia Pike, Suite 101 Arlington, Virgi...
#
#       city_fix        county_fix    zip  visit_date  time_of_visit  \
# 0    Arlington  Arlington County  22206  2023-07-01  Early Evening
# 1    Arlington  Arlington County  22206  2023-01-01      Afternoon
# 2    Arlington  Arlington County  22206  2022-11-01      Afternoon
# 3    Arlington  Arlington County  22206  2022-10-01      Afternoon
# 4    Arlington  Arlington County  22206  2022-08-01      Afternoon
# ..         ...               ...    ...         ...            ...
# 196  Arlington  Arlington County  22204  2021-05-01        Morning
# 197  Arlington  Arlington County  22204  2021-03-01        Morning
# 198  Arlington  Arlington County  22204  2020-08-01          Night
# 199  Arlington  Arlington County  22204  2020-02-01          Night
# 200  Arlington  Arlington County  22204  2019-12-01  Early Evening
#
#     paid_to_house extra_tip  \
# 0              80       200
# 1              80       100
# 2              80       120
# 3              60       120
# 4              80       100
# ..            ...       ...
# 196            80        40
# 197            80        40
# 198            80        40
# 199            80        40
# 200            70        40
#
#                                               message1  \
# 0    Second time here - easy to find, not so easy t...
# 1    I tried this place in Arlington, ok parlor, ma...
# 2    Place while kinda off the beaten path, is righ...
# 3    My 3rd time visiting and prob best experience ...
# 4    Stopped in again to see the talent. saw Kim la...
# ..                                                 ...
# 196  Pretty average AMP located in an office buildi...
# 197  This place always delivers, I got my last serv...
# 198  Coco was made to please... geez what a lovely ...
# 199  Coco's a good girl, average body but she was p...
# 200  TS is broken, I should have gone with my gut a...
#
#                                               message2  \
# 0    Coco was very pleasant. The massage was one le...
# 1    Called ahead but another monger got there befo...
# 2    1TLT reader/reviewer.  I've never posted and a...
# 3    Called ahead and she told me to walk in. Cute ...
# 4    Went over to and did some shopping then texted...
# ..                                                 ...
# 196  First time at this parlor. Walked in, I was gr...
# 197  I made a stop and paid Coco a quick visit, typ...
# 198  Her massage was pretty good. Not too much pres...
# 199  It took a couple of minutes for Coco to come i...
# 200  The massage was terrible, so I stuck with it h...
#
#                                                    url  review_id  \
# 0    /erotic-massage-shirlington-therapy-arlington-...  8229877.0
# 1    /erotic-massage-shirlington-therapy-arlington-...  8229878.0
# 2    /erotic-massage-shirlington-therapy-arlington-...  8229879.0
# 3    /erotic-massage-shirlington-therapy-arlington-...  8229880.0
# 4    /erotic-massage-shirlington-therapy-arlington-...  8229881.0
# ..                                                 ...        ...
# 196  /erotic-massage-live-massage-spa-arlington-va-...  8230917.0
# 197  /erotic-massage-live-massage-spa-arlington-va-...  8230918.0
# 198  /erotic-massage-live-massage-spa-arlington-va-...  8230919.0
# 199  /erotic-massage-live-massage-spa-arlington-va-...  8230920.0
# 200  /erotic-massage-live-massage-spa-arlington-va-...  8230921.0
#
#     review_head_date finger kiss lick   fs breast_play blowjob ass_play  \
# 0         2023-07-16      o    X    X  CFS           o     CBJ        X
# 1         2023-01-13      X    X    X    X           X     CBJ        X
# 2         2022-11-17      X    X    X    X           o     CBJ        o
# 3         2022-11-03      X    X    X    X           X     CBJ        X
# 4         2022-08-01      X    X    X    X           X     CBJ        X
# ..               ...    ...  ...  ...  ...         ...     ...      ...
# 196       2021-05-26      X    X    X    X           X       X        X
# 197       2021-03-04      X    X    X    X           X       X        X
# 198       2020-08-19      X    X    X    X           o       X        o
# 199       2020-02-28      X    X    X    X           o       X        o
# 200       2019-12-15      X    X    X    X           X       X        X
#
#     hand_job prostate_massage
# 0          o                X
# 1          o                X
# 2          o                X
# 3          o                X
# 4          o                X
# ..       ...              ...
# 196        o                X
# 197        o                X
# 198        o                X
# 199        o                X
# 200        o                X
#
# [200 rows x 27 columns]

# %%
#df_kitems.head(50)

def calculate_sum(row):
    total = 0
    for key, val in values.items():
        if row[key] not in bad_list:
            total += val
    return total

# Load original DataFrame here (df_kitems)

# Perform necessary conversions outside the loop
today = date.today()
value05 = today - datetime.timedelta(days=365)


# Create new columns to store calculated values


#df_kitems['date_interpolation'] = np.nan
#df_kitems['value_illicit'] = np.nan
#df_kitems['final_value'] = np.nan
#df_kitems['IMB_label'] = np.nan

# Define values and bad_list as you did in your code
values = {
    'finger': 0.075,
    'kiss': 0.025,
    'lick': 0.075,
    'breast_play': 0.025, 
    'blowjob': 0.35,
    'ass_play': 0.025,
    'hand_job': 0.35,
    'prostate_massage': 0.075
}
bad_list = set(['X', 'x', '', '?'])

illicit_threshold = 0.3

# Iterate through unique business IDs
for business_id in tqdm(df_kitems['identifier'].unique()):
    
    entry = len(df_kitems[df_kitems['identifier']==business_id])
    
    mask = df_kitems['identifier'] == business_id
    temporal_df = df_kitems[mask]
    
    list_dates = temporal_df['review_head_date']
    list_dates_diff = (today - list_dates).dt.days


    xp = [0, (today - value05).days, (today - list_dates.min()).days]
    fp = [1, 0.5, 0]
    interpolations = np.interp(list_dates_diff, xp, fp)

    value_illicit = temporal_df.apply(calculate_sum, axis=1)
    
    df_kitems.loc[mask, 'date_interpolation'] = interpolations
    df_kitems.loc[mask, 'value_illicit'] = value_illicit
    df_kitems.loc[mask, 'final_value'] = interpolations * value_illicit
    
    temporal_df.loc[mask, 'date_interpolation'] = interpolations
    temporal_df.loc[mask, 'value_illicit'] = value_illicit
    temporal_df.loc[mask, 'final_value'] = interpolations * value_illicit
        
    exit = len(temporal_df)
    if entry == exit:        

        sum_date_interpolation = temporal_df['date_interpolation'].sum()
        sum_final_value = temporal_df['final_value'].sum()

         # Calculate IMB_label and classify as illicit or not_illicit

        if sum_date_interpolation != 0:
            imb_label = sum_final_value / sum_date_interpolation
            df_kitems.loc[mask, 'IMB_label'] = imb_label
        
            # Label as illicit or not_illicit based on threshold
            if imb_label >= illicit_threshold:
                df_kitems.loc[mask, 'Activity_Label'] = 'illicit'
            elif imb_label <= 0.35 and imb_label >= 0.25:
                df_kitems.loc[mask,'Activity_Label'] = 'questionable_illicit'
            else:
                df_kitems.loc[mask, 'Activity_Label'] = 'not_illicit'
        else:
            df_kitems.loc[mask, 'IMB_label'] = np.nan
            df_kitems.loc[mask, 'Activity_Label'] = np.nan
        
        
#thisfinal
#whatveer you want
print (time.time() - start_time, 's')
#df_kitems.head(50)

#df_kitems.to_excel('/Users/emmabarnes/Documents/some more xlsx/reviews_3year_random_illicit_class.xlsx')
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]/var/folders/9c/0yt0mgkx087djr38wnxdhxmh0000gn/T/ipykernel_98600/2766530831.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temporal_df.loc[mask, 'date_interpolation'] = interpolations
# /var/folders/9c/0yt0mgkx087djr38wnxdhxmh0000gn/T/ipykernel_98600/2766530831.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temporal_df.loc[mask, 'value_illicit'] = value_illicit
# /var/folders/9c/0yt0mgkx087djr38wnxdhxmh0000gn/T/ipykernel_98600/2766530831.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temporal_df.loc[mask, 'final_value'] = interpolations * value_illicit
# /var/folders/9c/0yt0mgkx087djr38wnxdhxmh0000gn/T/ipykernel_98600/2766530831.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temporal_df.loc[mask, 'date_interpolation'] = interpolations
# /var/folders/9c/0yt0mgkx087djr38wnxdhxmh0000gn/T/ipykernel_98600/2766530831.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temporal_df.loc[mask, 'value_illicit'] = value_illicit
# /var/folders/9c/0yt0mgkx087djr38wnxdhxmh0000gn/T/ipykernel_98600/2766530831.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temporal_df.loc[mask, 'final_value'] = interpolations * value_illicit
# /var/folders/9c/0yt0mgkx087djr38wnxdhxmh0000gn/T/ipykernel_98600/2766530831.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temporal_df.loc[mask, 'date_interpolation'] = interpolations
# /var/folders/9c/0yt0mgkx087djr38wnxdhxmh0000gn/T/ipykernel_98600/2766530831.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temporal_df.loc[mask, 'value_illicit'] = value_illicit
# /var/folders/9c/0yt0mgkx087djr38wnxdhxmh0000gn/T/ipykernel_98600/2766530831.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temporal_df.loc[mask, 'final_value'] = interpolations * value_illicit
# /var/folders/9c/0yt0mgkx087djr38wnxdhxmh0000gn/T/ipykernel_98600/2766530831.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temporal_df.loc[mask, 'date_interpolation'] = interpolations
# /var/folders/9c/0yt0mgkx087djr38wnxdhxmh0000gn/T/ipykernel_98600/2766530831.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temporal_df.loc[mask, 'value_illicit'] = value_illicit
# /var/folders/9c/0yt0mgkx087djr38wnxdhxmh0000gn/T/ipykernel_98600/2766530831.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temporal_df.loc[mask, 'final_value'] = interpolations * value_illicit
# /var/folders/9c/0yt0mgkx087djr38wnxdhxmh0000gn/T/ipykernel_98600/2766530831.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temporal_df.loc[mask, 'date_interpolation'] = interpolations
# /var/folders/9c/0yt0mgkx087djr38wnxdhxmh0000gn/T/ipykernel_98600/2766530831.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temporal_df.loc[mask, 'value_illicit'] = value_illicit
# /var/folders/9c/0yt0mgkx087djr38wnxdhxmh0000gn/T/ipykernel_98600/2766530831.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temporal_df.loc[mask, 'final_value'] = interpolations * value_illicit
# /var/folders/9c/0yt0mgkx087djr38wnxdhxmh0000gn/T/ipykernel_98600/2766530831.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temporal_df.loc[mask, 'date_interpolation'] = interpolations
# /var/folders/9c/0yt0mgkx087djr38wnxdhxmh0000gn/T/ipykernel_98600/2766530831.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temporal_df.loc[mask, 'value_illicit'] = value_illicit
# /var/folders/9c/0yt0mgkx087djr38wnxdhxmh0000gn/T/ipykernel_98600/2766530831.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temporal_df.loc[mask, 'final_value'] = interpolations * value_illicit
#  60%|██████    | 6/10 [00:00<00:00, 54.74it/s]/var/folders/9c/0yt0mgkx087djr38wnxdhxmh0000gn/T/ipykernel_98600/2766530831.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temporal_df.loc[mask, 'date_interpolation'] = interpolations
# /var/folders/9c/0yt0mgkx087djr38wnxdhxmh0000gn/T/ipykernel_98600/2766530831.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temporal_df.loc[mask, 'value_illicit'] = value_illicit
# /var/folders/9c/0yt0mgkx087djr38wnxdhxmh0000gn/T/ipykernel_98600/2766530831.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temporal_df.loc[mask, 'final_value'] = interpolations * value_illicit
# /var/folders/9c/0yt0mgkx087djr38wnxdhxmh0000gn/T/ipykernel_98600/2766530831.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temporal_df.loc[mask, 'date_interpolation'] = interpolations
# /var/folders/9c/0yt0mgkx087djr38wnxdhxmh0000gn/T/ipykernel_98600/2766530831.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temporal_df.loc[mask, 'value_illicit'] = value_illicit
# /var/folders/9c/0yt0mgkx087djr38wnxdhxmh0000gn/T/ipykernel_98600/2766530831.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temporal_df.loc[mask, 'final_value'] = interpolations * value_illicit
# /var/folders/9c/0yt0mgkx087djr38wnxdhxmh0000gn/T/ipykernel_98600/2766530831.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temporal_df.loc[mask, 'date_interpolation'] = interpolations
# /var/folders/9c/0yt0mgkx087djr38wnxdhxmh0000gn/T/ipykernel_98600/2766530831.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temporal_df.loc[mask, 'value_illicit'] = value_illicit
# /var/folders/9c/0yt0mgkx087djr38wnxdhxmh0000gn/T/ipykernel_98600/2766530831.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temporal_df.loc[mask, 'final_value'] = interpolations * value_illicit
# /var/folders/9c/0yt0mgkx087djr38wnxdhxmh0000gn/T/ipykernel_98600/2766530831.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temporal_df.loc[mask, 'date_interpolation'] = interpolations
# /var/folders/9c/0yt0mgkx087djr38wnxdhxmh0000gn/T/ipykernel_98600/2766530831.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temporal_df.loc[mask, 'value_illicit'] = value_illicit
# /var/folders/9c/0yt0mgkx087djr38wnxdhxmh0000gn/T/ipykernel_98600/2766530831.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tem
# 47       2018-05-21      X    X    X    X           X     CBJ        X
# 48       2018-04-24      X    X    X    X           X     CBJ        X
# 49       2018-04-05      X    X    X    X           X     CBJ        X
#
#    hand_job prostate_massage  date_interpolation  value_illicit  final_value  \
# 0         o                X            0.891781          0.800     0.713425
# 1         o                X            0.639726          0.700     0.447808
# 2         o                X            0.561644          0.750     0.421233
# 3         o                X            0.542466          0.700     0.379726
# 4         o                X            0.486136          0.700     0.340295
# 5         o                X            0.473371          0.700     0.331360
# 6         ?                X            0.451585          0.375     0.169344
# 7         X                X            0.427817          0.425     0.181822
# 8         X                X            0.414613          0.425     0.176210
# 9         X                X            0.398548          0.550     0.219201
# 10        X                X            0.384023          0.550     0.211213
# 11        X                X            0.383583          0.350     0.134254
# 12        o                ?            0.382262          0.825     0.315366
# 13        X                X            0.369498          0.350     0.129324
# 14        o                ?            0.368398          0.825     0.303928
# 15        o                ?            0.352773          0.825     0.291038
# 16        o                ?            0.335827          0.825     0.277058
# 17        X                X            0.328345          0.350     0.114921
# 18        X                X            0.316901          0.450     0.142606
# 19        X                X            0.290493          0.450     0.130722
# 20        ?                ?            0.289613          0.500     0.144806
# 21        X                X            0.287632          0.450     0.129434
# 22        ?                ?            0.286752          0.575     0.164882
# 23        X                X            0.272887          0.550     0.150088
# 24        X                X            0.258803          0.550     0.142342
# 25        ?                ?            0.256602          0.000     0.000000
# 26        ?                ?            0.249120          0.000     0.000000
# 27        o                X            0.248239          0.825     0.204798
# 28        o                ?            0.242298          0.900     0.218068
# 29        o                ?            0.233275          0.825     0.192452
# 30        o                X            0.232394          0.850     0.197535
# 31        o                X            0.220290          0.850     0.187247
# 32        o                X            0.200044          0.850     0.170037
# 33        o                X            0.197183          0.800     0.157746
# 34        o                X            0.195863          0.925     0.181173
# 35        o                X            0.192342          0.700     0.134639
# 36        o                ?            0.181778          0.700     0.127245
# 37        o                X            0.181118          0.800     0.144894
# 38        o                X            0.181118          0.700     0.126783
# 39        o                o            0.175836          0.925     0.162649
# 40        o                X            0.169674          0.350     0.059386
# 41        o                X            0.169234          0.475     0.080386
# 42        o                ?            0.168574          0.800     0.134859
# 43        o                X            0.165053          0.925     0.152674
# 44        o                X            0.163512          0.750     0.122634
# 45        o                X            0.152289          0.700     0.106602
# 46        o                X            0.149648          0.700     0.104754
# 47        o                X            0.148768          0.700     0.104137
# 48        o                X            0.142826          0.700     0.099978
# 49        o                X            0.138644          0.700     0.097051
#
#     IMB_label Activity_Label
# 0    0.622335        illicit
# 1    0.622335        illicit
# 2    0.622335        illicit
# 3    0.622335        illicit
# 4    0.622335        illicit
# 5    0.622335        illicit
# 6    0.622335        illicit
# 7    0.622335        illicit
# 8    0.622335        illicit
# 9    0.622335        illicit
# 10   0.622335        illicit
# 11   0.622335        illicit
# 12   0.622335        illicit
# 13   0.622335        illicit
# 14   0.622335        illicit
# 15   0.622335        illicit
# 16   0.622335        illicit
# 17   0.622335        illicit
# 18   0.622335        illicit
# 19   0.622335        illicit
# 20   0.622335        illicit
# 21   0.622335        illicit
# 22   0.622335        illicit
# 23   0.622335        illicit
# 24   0.622335        illicit
# 25   0.622335        illicit
# 26   0.622335        illicit
# 27   0.622335        illicit
# 28   0.622335        illicit
# 29   0.622335        illicit
# 30   0.622335        illicit
# 31   0.622335        illicit
# 32   0.622335        illicit
# 33   0.622335        illicit
# 34   0.622335        illicit
# 35   0.622335        illicit
# 36   0.622335        illicit
# 37   0.622335        illicit
# 38   0.622335        illicit
# 39   0.622335        illicit
# 40   0.622335        illicit
# 41   0.622335        illicit
# 42   0.622335        illicit
# 43   0.622335        illicit
# 44   0.622335        illicit
# 45   0.622335        illicit
# 46   0.622335        illicit
# 47   0.622335        illicit
# 48   0.622335        illicit
# 49   0.622335        illicit

# %%
def calculate_sum(row):
    total = 0
    for key, val in values.items():
        if row[key] not in bad_list:
            total += val
    return total

# Load original DataFrame here (df_kitems)

# Perform necessary conversions outside the loop
today = date.today()
value05 = today - datetime.timedelta(days=365)

# Define values and bad_list as you did in your code
values = {
    'finger': 0.075,
    'kiss': 0.025,
    'lick': 0.075,
    'breast_play': 0.025, 
    'blowjob': 0.35,
    'ass_play': 0.025,
    'hand_job': 0.35,
    'prostate_massage': 0.075
}
bad_list = set(['X', 'x', '', '?'])

illicit_threshold = 0.3

# Iterate through unique business IDs
for business_id in tqdm(df_kitems['identifier'].unique()):
    
    entry = len(df_kitems[df_kitems['identifier']==business_id])
    
    mask = df_kitems['identifier'] == business_id
    temporal_df = df_kitems[mask].copy()  # Create a copy of the DataFrame
    
    list_dates = temporal_df['review_head_date']
    list_dates_diff = (today - list_dates).dt.days

    xp = [0, (today - value05).days, (today - list_dates.min()).days]
    fp = [1, 0.5, 0]
    interpolations = np.interp(list_dates_diff, xp, fp)

    value_illicit = temporal_df.apply(calculate_sum, axis=1)
    
    df_kitems.loc[mask, 'date_interpolation'] = interpolations
    df_kitems.loc[mask, 'value_illicit'] = value_illicit
    df_kitems.loc[mask, 'final_value'] = interpolations * value_illicit
    
    temporal_df.loc[:, 'date_interpolation'] = interpolations
    temporal_df.loc[:, 'value_illicit'] = value_illicit
    temporal_df.loc[:, 'final_value'] = interpolations * value_illicit
    
    exit = len(temporal_df)
    if entry == exit:
        sum_date_interpolation = temporal_df['date_interpolation'].sum()
        sum_final_value = temporal_df['final_value'].sum()

        # Calculate IMB_label and classify as illicit or not_illicit
        if sum_date_interpolation != 0:
            imb_label = sum_final_value / sum_date_interpolation
            df_kitems.loc[mask, 'IMB_label'] = imb_label

            # Label as illicit or not_illicit based on threshold
            if imb_label >= illicit_threshold:
                df_kitems.loc[mask, 'Activity_Label'] = 'illicit'
            elif imb_label <= 0.35 and imb_label >= 0.25:
                df_kitems.loc[mask, 'Activity_Label'] = 'questionable_illicit'
            else:
                df_kitems.loc[mask, 'Activity_Label'] = 'not_illicit'
        else:
            df_kitems.loc[mask, 'IMB_label'] = np.nan
            df_kitems.loc[mask, 'Activity_Label'] = np.nan


df_kitems = df_kitems.loc[:, ['IMB_label', 'Activity_Label']]

print (time.time() - start_time, 's')
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 206.15it/s]
# 1475.602030992508 s

# %%
df_kitems.head()
# Out:
#    IMB_label Activity_Label
# 0   0.622335        illicit
# 1   0.622335        illicit
# 2   0.622335        illicit
# 3   0.622335        illicit
# 4   0.622335        illicit
